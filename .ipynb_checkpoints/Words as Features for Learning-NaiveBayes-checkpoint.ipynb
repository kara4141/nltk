# %%
import nltk
import random 
from nltk.corpus import movie_reviews

# %%
documents = [(list(movie_reviews.words(fileid)),category)
            for category in movie_reviews.categories()
            for fileid in movie_reviews.fileids(category)]

random.shuffle(documents)

print (documents[1])
# Out:
# (['old', 'soldiers', 'never', 'die', ',', 'they', 'just', 'turn', 'into', 'cliches', 'soldier', 'a', 'film', 'review', 'by', 'michael', 'redman', 'copyright', '1998', 'by', 'michael', 'redman', 'the', 'warrior', 'and', 'the', 'lover', 'are', 'two', 'personality', 'aspects', 'that', 'find', 'it', 'difficult', 'to', 'exist', 'in', 'the', 'same', 'body', '.', 'jungian', 'archetypes', ',', 'these', 'two', 'opposites', 'need', 'each', 'other', 'to', 'create', 'a', 'whole', ',', 'but', 'it', "'", 's', 'difficult', 'to', 'integrate', 'both', '.', 'often', 'we', "'", 'll', 'encounter', 'lovers', 'who', 'think', 'everything', 'is', 'just', 'wonderful', 'and', ',', 'with', 'the', 'help', 'of', 'jung', "'", 's', 'magician', ',', 'sit', 'around', 'imagining', 'grand', 'schemes', '.', 'without', 'the', 'drive', 'to', 'manifest', 'their', 'plans', ',', 'much', 'less', 'the', 'wisdom', 'to', 'recognize', 'the', 'darkness', ',', 'all', 'they', 'have', 'are', 'dreams', '.', 'warriors', 'on', 'the', 'other', 'hand', ',', 'are', 'ready', 'to', 'go', 'to', 'war', 'at', 'the', 'drop', 'of', 'a', 'hat', ',', 'and', 'will', 'do', 'combat', 'with', 'every', 'last', 'bit', 'of', 'their', 'energy', '.', 'they', 'don', "'", 't', 'care', 'enough', 'about', 'anything', 'to', 'know', 'what', "'", 's', 'worth', 'fighting', 'for', ':', 'gladiators', 'who', 'live', 'only', 'for', 'the', 'battle', '.', 'this', 'dichotomy', 'not', 'only', 'describes', 'individuals', 'that', 'we', 'all', 'know', ',', 'but', 'can', 'also', 'illustrate', 'societies', '.', 'america', 'during', 'the', 'late', 'sixties', 'was', 'a', 'conflict', 'between', 'old', 'style', 'cold', 'warriors', 'and', 'the', 'new', 'hippie', 'lovers', '.', 'todd', '3465', '(', 'kurt', 'russell', ')', 'is', 'a', 'living', ',', 'breathing', 'archetype', '.', 'chosen', 'from', 'birth', 'as', 'a', 'soldier', ',', 'he', 'is', 'raised', 'by', 'the', 'government', 'to', 'be', 'a', 'killing', 'machine', '.', 'his', 'childhood', 'is', 'cruelty', 'and', 'competition', '.', 'he', 'is', 'indoctrinated', 'with', 'the', 'big', 'rules', '.', 'never', 'question', 'authority', '.', 'winning', 'is', 'everything', '.', 'strength', 'beats', 'knowledge', '.', 'a', 'veteran', 'of', 'numerous', 'intergalactic', 'wars', ',', 'todd', 'is', '40', 'and', 'he', "'", 's', 'obsolete', '.', 'a', 'new', 'generation', 'of', 'genetically', 'engineered', 'soldiers', 'are', 'faster', 'and', 'stronger', '.', 'left', 'for', 'dead', 'after', 'a', 'test', 'battle', 'with', 'the', 'best', 'of', 'the', 'new', 'killers', ',', 'caine', '607', '(', 'jason', 'scott', 'lee', ')', ',', 'he', "'", 's', 'unceremoniously', 'dumped', 'as', 'trash', 'on', 'arcadia', '234', ',', 'a', 'garbage', 'world', '.', 'obviously', 'our', 'hero', 'is', 'still', 'alive', '.', 'he', 'finds', 'a', 'group', 'of', 'shipwrecked', 'settlers', 'abandoned', 'on', 'the', 'planet', 'who', 'nurse', 'him', 'back', 'to', 'health', '.', 'when', 'the', 'peace', '-', 'loving', 'colonists', 'get', 'a', 'good', 'look', 'at', 'who', 'todd', 'is', ',', 'they', 'are', 'afraid', 'of', 'him', 'and', 'he', 'is', 'exiled', 'to', 'live', 'by', 'himself', 'amid', 'the', 'junk', 'on', 'an', 'environmentally', 'hostile', 'world', '.', 'they', 'are', 'the', 'other', 'good', 'guys', '.', 'these', 'lovers', 'find', 'that', 'they', 'need', 'a', 'warrior', 'when', 'the', 'military', 'coincidentally', 'chooses', 'this', 'world', 'to', 'conduct', 'exercises', 'for', 'their', 'improved', 'human', 'weapons', '.', 'todd', 'finds', 'himself', 'in', 'the', 'role', 'of', 'protector', '.', 'what', 'could', 'have', 'been', 'a', 'fascinating', 'look', 'at', 'the', 'roles', 'played', 'in', 'our', 'culture', 'and', 'the', 'fears', 'of', 'an', 'ultra', '-', 'right', 'wing', 'future', 'is', 'ruined', 'by', 'turning', 'the', 'film', 'into', 'a', 'cartoon', '.', 'the', 'effects', 'are', 'mostly', 'second', '-', 'rate', 'explosions', 'or', 'jerky', 'slow', 'motion', '.', 'the', 'plot', 'is', 'old', 'hat', '.', 'we', 'do ...

# %%
all_words = []
for w in movie_reviews.words():
    all_words.append(w.lower())
    
all_words = nltk.FreqDist(all_words)

words_features = list (all_words.keys())[:3000]

def find_features(document):
    words = set (document)
    features = {}
    for w in words_features:
        features[w] = {w in words}
    return features
print ((find_features(movie_reviews.words('neg/cv000_29416.txt'))))
featuresets = [(find_feature(rev),category) for (rev,category) in documents]
# Out:
# {'benzali': {False}, 'runway': {False}, 'gobbledygook': {False}, 'innocents': {False}, 'plunges': {False}, 'sacred': {False}, 'blackmailing': {False}, 'flares': {False}, 'ensuing': {False}, 'hoisting': {False}, 'immin': {False}, 'landslide': {False}, 'spiraling': {False}, 'deflower': {False}, 'xiii': {False}, 'terms': {False}, 'transitory': {False}, 'ryan_': {False}, 'masquerade': {False}, 'bumped': {False}, 'cook': {False}, 'unemployment': {False}, 'nuptials': {False}, 'plying': {False}, 'surrealist': {False}, 'gadget': {False}, 'arrietty': {False}, 'untrusting': {False}, 'ike': {False}, 'spirituality': {False}, 'antipathetic': {False}, 'sickens': {False}, 'denouncement': {False}, 'exacerbates': {False}, 'speedily': {False}, 'troublemaker': {False}, 'koukoula': {False}, 'fiqure': {False}, 'idolizes': {False}, 'apparel': {False}, 'processed': {False}, 'graders': {False}, 'instances': {False}, 'burton': {False}, 'insistence': {False}, 'hostages': {False}, 'misperception': {False}, 'respectable': {False}, 'exorbitantly': {False}, 'obligingly': {False}, 'blunt': {False}, 'caraboo': {False}, 'aw': {False}, 'label': {False}, 'inconspicuously': {False}, 'whitehouse': {False}, 'heartbreaking': {False}, 'uninspiring': {False}, 'shout': {False}, 'guilifoyle': {False}, 'totoro': {False}, 'fox': {False}, 'mcnamara': {False}, 'impolite': {False}, 'carrion': {False}, 'dingy': {False}, 'departing': {False}, 'capitalizes': {False}, 'hypnotize': {False}, 'santanico': {False}, 'memo': {False}, 'compardre': {False}, 'designs': {False}, 'epigrams': {False}, 'closeups': {False}, 'goliath': {False}, 'earthquake': {False}, 'feces': {False}, 'effervescently': {False}, 'unprintable': {False}, 'indifferent': {False}, 'piracy': {False}, 'decreasing': {False}, 'gies': {False}, 'grandeur': {False}, 'harries': {False}, 'resuscitate': {False}, 'fours': {False}, 'declines': {False}, 'maniacle': {False}, 'fostered': {False}, 'yasmin': {False}, 'palestinians': {False}, 'puritanical': {False}, 'pelvis': {False}, 'manipulates': {False}, 'uncertainty': {False}, 'order': {False}, 'bleached': {False}, 'deviance': {False}, 'holds': {True}, 'lorraine': {False}, 'jeopardise': {False}, 'bufford': {False}, 'thoroughly': {False}, 'thorne': {False}, 'armi': {False}, 'creeper': {False}, 'disrepair': {False}, 'listening': {False}, 'bouquet': {False}, 'wachowski': {False}, '216': {False}, '92re': {False}, 'showgirls': {False}, 'crimefighting': {False}, 'incorporates': {False}, 'sexually': {False}, 'pros': {False}, 'throbbing': {False}, 'trifecta': {False}, 'bashes': {False}, 'tally': {False}, 'pursuer': {False}, 'loli': {False}, 'opposing': {False}, 'amanda': {False}, 'inescapable': {False}, '48': {False}, 'ashbrook': {False}, 'retrieving': {False}, 'italicize': {False}, 'overbearing': {False}, 'capano': {False}, 'tavern': {False}, 'crusher': {False}, 'leggings': {False}, 'elena': {False}, 'chronicle': {False}, 'economics': {False}, 'moralizing': {False}, 'embodied': {False}, 'returns': {False}, 'roots': {False}, 'smattering': {False}, 'videos': {False}, 'contacted': {False}, 'gusto': {False}, 'sometime': {False}, 'counting': {False}, 'middlemen': {False}, 'ussr': {False}, 'vigo': {False}, 'degenerating': {False}, 'preserves': {False}, 'waking': {False}, 'childbirth': {False}, 'paneled': {False}, 'insectopia': {False}, 'injury': {False}, 'vigorous': {False}, 'bladders': {False}, 'timecop': {False}, 'bartusiak': {False}, 'laudible': {False}, 'scrappy': {False}, 'amyls': {False}, 'flynt': {False}, 'dislike': {False}, 'relling': {False}, 'verbal': {False}, 'bead': {False}, 'redford': {False}, 'scenario': {False}, 'dedicates': {False}, 'freebie': {False}, 'phillippe': {False}, 'ya': {False}, 'deficient': {False}, 'purposeful': {False}, 'ribbon': {False}, 'home': {False}, 'carlo': {False}, '107': {False}, '2000': {False}, 'naturalistic': {False}, 'bronson': {False}, 'touchingly': {False}, 'conway': {False}, 'oumph': {False}, 'smokejumpers': {False}, 'cracker': {False}, 'drowning ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-063f8c9dcb40> in <module>()
#      14     return features
#      15 print ((find_features(movie_reviews.words('neg/cv000_29416.txt'))))
# ---> 16 featuresets = [(find_feature(rev),category) for (rev,category) in documents]
#
# <ipython-input-21-063f8c9dcb40> in <listcomp>(.0)
#      14     return features
#      15 print ((find_features(movie_reviews.words('neg/cv000_29416.txt'))))
# ---> 16 featuresets = [(find_feature(rev),category) for (rev,category) in documents]
#
# NameError: name 'find_feature' is not defined

# %%
#print(all_words["stupid"])

# %%
training_set = featuresets[:1900] 
testing_set = featuresets[1900:]

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [raw]
# print ("Naive Bayes Algo accuracy:" , (nltk.classify.accuracy(classifier,testing_set))

# %%
print ("Naive Bayes Algo accuracy:" , (nltk.classify.accuracy(classifier,testing_set))*100)

# %%
classifier.show_most_informative_features(15)
